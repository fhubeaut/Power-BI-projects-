# %%
#Lets analyze the data before diving into the dashboard building part

# %%
import pandas as pd

# %%
shots = pd.read_csv("C:\\Users\\fhube\\Downloads\\2021 Python for Machine Learning Data Science Masterclass\\1.2\\UNZIP_FOR_NOTEBOOKS_FINAL\\Shoot Model\\NBA Shot Locations 1997 - 2020.csv")

# %%
shots.head()
# Out:
#     Game ID  Game Event ID  Player ID Player Name     Team ID  \
# 0  29700427            389        100  Tim Legler  1610612764
# 1  29700427            406        100  Tim Legler  1610612764
# 2  29700427            475        100  Tim Legler  1610612764
# 3  29700427            487        100  Tim Legler  1610612764
# 4  29700427            497        100  Tim Legler  1610612764
#
#             Team Name  Period  Minutes Remaining  Seconds Remaining  \
# 0  Washington Wizards       4                 11                 22
# 1  Washington Wizards       4                  9                 36
# 2  Washington Wizards       4                  3                  7
# 3  Washington Wizards       4                  1                 45
# 4  Washington Wizards       4                  0                 45
#
#   Action Type  ... Shot Zone Area  Shot Zone Range Shot Distance X Location  \
# 0   Jump Shot  ...  Right Side(R)         8-16 ft.            15        117
# ...

# %%
shots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4729512 entries, 0 to 4729511
# Data columns (total 22 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Game ID            int64
#  1   Game Event ID      int64
#  2   Player ID          int64
#  3   Player Name        object
#  4   Team ID            int64
#  5   Team Name          object
#  6   Period             int64
#  7   Minutes Remaining  int64
#  8   Seconds Remaining  int64
#  9   Action Type        object
#  10  Shot Type          object
#  11  Shot Zone Basic    object
#  12  Shot Zone Area     object
#  13  Shot Zone Range    object
#  14  Shot Distance      int64
#  15  X Location         int64
#  16  Y Location         int64
#  17  Shot Made Flag     int64
#  18  Game Date          int64
#  19  Home Team          object
#  20  Away Team          object
#  21  Season Type        object
# dtypes: int64(12), object(10)
# memory usage: 793.8+ MB

# %%
shots.describe()
# Out:
#             Game ID  Game Event ID     Player ID       Team ID        Period  \
# count  4.729512e+06   4.729512e+06  4.729512e+06  4.729512e+06  4.729512e+06
# mean   2.314379e+07   2.501681e+02  1.639145e+05  1.610613e+09  2.477790e+00
# std    5.521124e+06   1.589274e+02  3.733497e+05  8.595674e+00  1.139482e+00
# min    2.000000e+07   1.000000e+00  3.000000e+00  1.610613e+09  1.000000e+00
# 25%    2.060015e+07   1.130000e+02  1.515000e+03  1.610613e+09  1.000000e+00
# 50%    2.120030e+07   2.450000e+02  2.550000e+03  1.610613e+09  2.000000e+00
# 75%    2.170117e+07   3.750000e+02  2.019370e+05  1.610613e+09  3.000000e+00
# max    4.990009e+07   1.012000e+03  1.629760e+06  1.610613e+09  8.000000e+00
#
#        Minutes Remaining  Seconds Remaining  Shot Distance    X Location  \
# count       4.729512e+06       4.729512e+06   4.729512e+06  4.729512e+06
# mean        5.332437e+00       2.873821e+01   1.208963e+01 -1.316958e+00
# ...

# %%
shots.describe().transpose()
# Out:
#                        count          mean           std           min  \
# Game ID            4729512.0  2.314379e+07  5.521124e+06  2.000000e+07
# Game Event ID      4729512.0  2.501681e+02  1.589274e+02  1.000000e+00
# Player ID          4729512.0  1.639145e+05  3.733497e+05  3.000000e+00
# Team ID            4729512.0  1.610613e+09  8.595674e+00  1.610613e+09
# Period             4729512.0  2.477790e+00  1.139482e+00  1.000000e+00
# Minutes Remaining  4729512.0  5.332437e+00  3.468664e+00  0.000000e+00
# Seconds Remaining  4729512.0  2.873821e+01  1.745678e+01  0.000000e+00
# Shot Distance      4729512.0  1.208963e+01  9.850088e+00  0.000000e+00
# X Location         4729512.0 -1.316958e+00  1.100864e+02 -2.500000e+02
# Y Location         4729512.0  7.634400e+01  8.703236e+01 -5.200000e+01
# Shot Made Flag     4729512.0  4.517832e-01  4.976698e-01  0.000000e+00
# Game Date          4729512.0  2.008996e+07  6.512593e+04  1.997103e+07
#
# ...

# %%
shots.sort_values('Shot Distance')
# Out:
#           Game ID  Game Event ID  Player ID     Player Name     Team ID  \
# 2055929  20800338            332     101109  Raymond Felton  1610612766
# 3981545  21701011             59     203076   Anthony Davis  1610612740
# 593936   20000514             25        238     Tyrone Hill  1610612755
# 1475758  20500579            148     101158    Orien Greene  1610612738
# 1475757  20500579            146     101158    Orien Greene  1610612738
# ...           ...            ...        ...             ...         ...
# 1010112  20200571            225        304   John Stockton  1610612762
# 2790464  21100969             91        255      Grant Hill  1610612756
# 1773627  20601202            244       2404    Chris Wilcox  1610612760
# 1389912  20400314            457       2549     Chris Kaman  1610612746
# 2624876  21000435            132       2581     Steve Blake  1610612747
#
#                     Team Name  Period  Minutes Remaining  Seconds Remaining  \
# ...

# %%
shots.corr()
# Out:
#                     Game ID  Game Event ID  Player ID   Team ID    Period  \
# Game ID            1.000000      -0.012543  -0.062916 -0.002681 -0.001979
# Game Event ID     -0.012543       1.000000   0.141287 -0.009316  0.934033
# Player ID         -0.062916       0.141287   1.000000 -0.004986  0.017719
# Team ID           -0.002681      -0.009316  -0.004986  1.000000  0.000696
# Period            -0.001979       0.934033   0.017719  0.000696  1.000000
# Minutes Remaining  0.000004      -0.252865  -0.003752 -0.000554 -0.027226
# Seconds Remaining -0.000576      -0.020889   0.000959 -0.000507  0.000616
# Shot Distance     -0.008207       0.044887   0.017473 -0.010092  0.029715
# X Location        -0.002050       0.000586   0.001564 -0.001272 -0.000539
# Y Location        -0.014602       0.053370   0.049995 -0.013924  0.025293
# Shot Made Flag    -0.005117      -0.018967   0.001608  0.000890 -0.018169
# Game Date         -0.199343       0.158031   0.511525 -0.015235  0.004505
#
# ...

# %%
shots[['X Location','Y Location']].corr()
# Out:
#             X Location  Y Location
# X Location     1.00000     0.01378
# Y Location     0.01378     1.00000

# %%
shots['X Location'].min()
# Out:
# -250

# %%
shots['Y Location'].min()
# Out:
# -52

# %%
shots['X Location'].max()
# Out:
# 250

# %%
shots['Y Location'].max()
# Out:
# 884

# %%
shots['Shot Made Flag'].value_counts()
# Out:
# 0    2592798
# 1    2136714
# Name: Shot Made Flag, dtype: int64

# %%
shots['Team Name'].unique()
# Out:
# array(['Washington Wizards', 'Utah Jazz', 'San Antonio Spurs',
#        'Atlanta Hawks', 'Toronto Raptors', 'Portland Trail Blazers',
#        'New York Knicks', 'Houston Rockets', 'Phoenix Suns', 'Miami Heat',
#        'Cleveland Cavaliers', 'Milwaukee Bucks', 'Los Angeles Clippers',
#        'Philadelphia 76ers', 'Denver Nuggets', 'Golden State Warriors',
#        'Orlando Magic', 'Dallas Mavericks', 'Seattle SuperSonics',
#        'Sacramento Kings', 'Los Angeles Lakers', 'Vancouver Grizzlies',
#        'Charlotte Hornets', 'New Jersey Nets', 'Chicago Bulls',
#        'Indiana Pacers', 'Boston Celtics', 'Detroit Pistons',
#        'Minnesota Timberwolves', 'Memphis Grizzlies',
#        'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans', 'LA Clippers'],
#       dtype=object)

# %%
shots.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 4729507    False
# 4729508    False
# 4729509    False
# 4729510    False
# 4729511    False
# Length: 4729512, dtype: bool

# %%
len(shots)
# Out:
# 4729512

# %%
shots.isna().sum()
# Out:
# Game ID              0
# Game Event ID        0
# Player ID            0
# Player Name          0
# Team ID              0
# Team Name            0
# Period               0
# Minutes Remaining    0
# Seconds Remaining    0
# Action Type          0
# Shot Type            0
# Shot Zone Basic      0
# Shot Zone Area       0
# Shot Zone Range      0
# Shot Distance        0
# X Location           0
# Y Location           0
# Shot Made Flag       0
# Game Date            0
# Home Team            0
# Away Team            0
# Season Type          0
# dtype: int64

# %%
shots['Team Name'].value_counts()[:10]

#teams with the most shots
# Out:
# Los Angeles Lakers       169375
# San Antonio Spurs        168651
# Golden State Warriors    167564
# Dallas Mavericks         163846
# Boston Celtics           163755
# Indiana Pacers           161985
# Phoenix Suns             161001
# Cleveland Cavaliers      160943
# Detroit Pistons          159842
# Chicago Bulls            159383
# Name: Team Name, dtype: int64

# %%
shots['Player Name'].value_counts()[:10]
# Out:
# Kobe Bryant        30220
# LeBron James       29658
# Dirk Nowitzki      26376
# Tim Duncan         24221
# Vince Carter       22677
# Carmelo Anthony    22526
# Paul Pierce        21877
# Kevin Garnett      21472
# Dwyane Wade        20677
# Allen Iverson      20284
# Name: Player Name, dtype: int64

# %%
Manu = shots.loc[shots['Player Name'].str.contains("Ginobili",case=False)]

# %%
Manu
# Out:
#           Game ID  Game Event ID  Player ID    Player Name     Team ID  \
# 951482   20200003            119       1938  Manu Ginobili  1610612759
# 951483   20200003            125       1938  Manu Ginobili  1610612759
# 951484   20200003            133       1938  Manu Ginobili  1610612759
# 951485   20200003            410       1938  Manu Ginobili  1610612759
# 951486   20200003            439       1938  Manu Ginobili  1610612759
# ...           ...            ...        ...            ...         ...
# 4704459  41700155            295       1938  Manu Ginobili  1610612759
# 4704460  41700155            307       1938  Manu Ginobili  1610612759
# 4704461  41700155            445       1938  Manu Ginobili  1610612759
# 4704462  41700155            467       1938  Manu Ginobili  1610612759
# 4704463  41700155            568       1938  Manu Ginobili  1610612759
#
#                  Team Name  Period  Minutes Remaining  Seconds Remaining  \
# ...

# %%
len(Manu)
# Out:
# 12468

# %%
Manu.describe()
# Out:
#             Game ID  Game Event ID  Player ID       Team ID        Period  \
# count  1.246800e+04   12468.000000    12468.0  1.246800e+04  12468.000000
# mean   2.442137e+07     240.991578     1938.0  1.610613e+09      2.469442
# std    7.622129e+06     141.982037        0.0  0.000000e+00      1.125243
# min    2.020000e+07       2.000000     1938.0  1.610613e+09      1.000000
# 25%    2.060068e+07     114.000000     1938.0  1.610613e+09      1.000000
# 50%    2.100043e+07     235.000000     1938.0  1.610613e+09      2.000000
# 75%    2.150120e+07     356.000000     1938.0  1.610613e+09      3.000000
# max    4.170016e+07     808.000000     1938.0  1.610613e+09      7.000000
#
#        Minutes Remaining  Seconds Remaining  Shot Distance    X Location  \
# count       12468.000000       12468.000000   12468.000000  12468.000000
# mean            4.818014          28.185274      13.580687      3.990616
# std             3.734276          17.676436      10.685879    120.714844
# ...

# %%
shots['Period'].unique()
# Out:
# array([4, 1, 2, 3, 5, 6, 7, 8], dtype=int64)

# %%
shots['Period'].value_counts()

#we need to transform the data and put that the period 5,6,7 and 8 are OT
#necesitamos transformar la data y poner que el period 5,6,7 y 8 son OT
# Out:
# 1    1241342
# 2    1179133
# 3    1157160
# 4    1117611
# 5      29324
# 6       4115
# 7        720
# 8        107
# Name: Period, dtype: int64

# %%
shots['Game Date'].max()
# Out:
# 20200311

# %%
shots['Game Date'].min()
# Out:
# 19971031
